# %% [markdown]
# ### Применение TSLearn к анализу временной серии с Dropout

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.datasets import CachedDatasets

# %%
from load_csv import df
# clear all indexes
df = df.reset_index(drop=True)
df1 = df[['Date','Infections']]
df1.reset_index(drop=True)
df1['Inf_day'] = df1['Infections'].diff().fillna(df1['Infections'])
l = df1['Date']
ts = df1['Inf_day']
data = ts.values
X = data.reshape(data.shape[0])
print(X)
# Out:
#             Infections  Dead  Recover  Infect_by_date  inf_day
# Date
# 28.03.2020           6     0        0               6      NaN
# 29.03.2020           6     0        0               6      0.0
# 30.03.2020           9     1        0               8      3.0
# 31.03.2020           9     1        0               8      0.0
# 01.04.2020           9     2        0               7      0.0
# ['Infections', 'Dead', 'Recover', 'Infect_by_date', 'inf_day']
# Date
# 28.03.2020   2020-03-28
# 29.03.2020   2020-03-29
# 30.03.2020   2020-03-30
# 31.03.2020   2020-03-31
# 01.04.2020   2020-04-01
#                 ...
# 30.05.2023   2023-05-30
# 06.06.2023   2023-06-06
# 13.06.2023   2023-06-13
# 20.06.2023   2023-06-20
# 27.06.2023   2023-06-27
# Name: Date, Length: 1149, dtype: datetime64[ns]
# Date
# 28.03.2020       0.0
# 29.03.2020       1.0
# 30.03.2020       2.0
# 31.03.2020       3.0
# 01.04.2020       4.0
#                ...
# 30.05.2023    1158.0
# 06.06.2023    1165.0
# 13.06.2023    1172.0
# 20.06.2023    1179.0
# 27.06.2023    1186.0
# Name: Date, Length: 1149, dtype: float64
# [ 6.  0.  3. ... 23. 11. 27.]
# C:\Users\Alex\AppData\Local\Temp\ipykernel_63392\3674077191.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Inf_day'] = df1['Infections'].diff().fillna(df1['Infections'])

# %%
# Normalize the data
import matplotlib.pyplot as plt
# Normalize the data
scaler = TimeSeriesScalerMeanVariance()
X_normalized = scaler.fit_transform([X])

X_n = X_normalized[0]
                                    
print(X_n)
#plt.plot(X_normalized)тся
# Out:
# [[-0.7141232 ]
#  [-0.75404669]
#  [-0.73408494]
#  ...
#  [-0.60100664]
#  [-0.68085362]
#  [-0.57439098]]

# %%
from tslearn.utils import to_time_series_dataset
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_n, X_n, test_size=0.2, random_state=42)
plt.plot(X_train)
plt.plot(X_test)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Set the number of units 20 - 100
UNITS = 100

# Build the GRU model
model = Sequential()
model.add(LSTM(units=UNITS, activation='relu', input_shape=(X_normalized.shape[1], X_normalized.shape[2])))
model.add(Dense(1))  # Output layer for regression
model.compile(optimizer='adam', loss='mse')

# %%
EPOCHS = 100
BATCH_SIZE = 30

# Train the model
model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 1149, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1149, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 1149, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1149, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).
#  1/31 [..............................] - ETA: 37s - loss: 1.2027WARNING:tensorflow:Model was constructed with shape (None, 1149, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1149, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 31/31 [==============================] - 2s 16ms/step - loss: 0.8918 - val_loss: 0.8509
# Epoch 2/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7189 - val_loss: 0.6607
# Epoch 3/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5142 - val_loss: 0.4113
# Epoch 4/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2881 - val_loss: 0.1834
# Epoch 5/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1071 - val_loss: 0.0409
# Epoch 6/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0199 - val_loss: 0.0047
# Epoch 7/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 10/100
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 11/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 12/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 13/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 14/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 15/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 16/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 17/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 18/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 19/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 20/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 21/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 22/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 23/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 24/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 25/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 26/100
# 31/31 [==============================] - 0s 2ms/step - loss: 9.6136e-04 - val_loss: 0.0014
# Epoch 27/100
# 31/31 [==============================] - 0s 3ms/step - loss: 9
-04
# Epoch 94/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.3400e-05 - val_loss: 8.2484e-05
# Epoch 95/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.4071e-05 - val_loss: 9.9874e-05
# Epoch 96/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.1488e-05 - val_loss: 7.2680e-05
# Epoch 97/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.1963e-05 - val_loss: 6.0104e-05
# Epoch 98/100
# 31/31 [==============================] - 0s 3ms/step - loss: 4.1296e-05 - val_loss: 8.6590e-05
# Epoch 99/100
# 31/31 [==============================] - 0s 2ms/step - loss: 3.8580e-05 - val_loss: 7.2664e-05
# Epoch 100/100
# 31/31 [==============================] - 0s 3ms/step - loss: 3.4148e-05 - val_loss: 7.3093e-05

# %%
# Make predictions on the entire dataset
print(X_n)
# Out:
# [[-0.7141232 ]
#  [-0.75404669]
#  [-0.73408494]
#  ...
#  [-0.60100664]
#  [-0.68085362]
#  [-0.57439098]]

# %%
# y_pred = model.predict(X_n.reshape(X_n.shape[0], X_n.shape[1], 1))
y_pred = model.predict(X_n)
# Print the predictions

print(y_pred)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 1149, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1149, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 36/36 [==============================] - 0s 855us/step
# [[-0.71295816]
#  [-0.75255674]
#  [-0.7327815 ]
#  ...
#  [-0.6005535 ]
#  [-0.6799108 ]
#  [-0.57408714]]

# %%
from sklearn.metrics import mean_squared_error
# Calculate Mean Squared Error (MSE) as a performance metric
mse = mean_squared_error(X_n, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 3.873539455250976e-05

# %%
plt.plot(X_n)
plt.plot(y_pred)

# %%
plt.plot(X_n-y_pred)

# %%
# Calculate mean and variance for inverse scaling

mu = np.mean(X)
var = np.var(X)
print(mu,var)
# Out:
# 113.32375979112271 22586.319896742993

# %%
# Inverse transform predictions to get them in their original scale
y_pred_original_scale = (y_pred * np.sqrt(var)) + mu

# %%
import pandas as pd
df_lstm = pd.DataFrame()

df_lstm['X'] = X

df_lstm['y_pred_original_scale'] = y_pred_original_scale

df_lstm['Err'] = df_lstm['y_pred_original_scale'] - df_lstm['X']

df_lstm['Err_Sqr'] = df_lstm['Err']**2

MSE = df_lstm['Err_Sqr'].sum() / len(df_lstm)

print(df_lstm)
print(MSE)
# Out:
#          X  y_pred_original_scale       Err   Err_Sqr
# 0      6.0               6.175087  0.175087  0.030655
# 1      0.0               0.223923  0.223923  0.050141
# 2      3.0               3.195885  0.195885  0.038371
# 3      0.0               0.223923  0.223923  0.050141
# 4      0.0               0.223923  0.223923  0.050141
# ...    ...                    ...       ...       ...
# 1144  76.0              75.859879 -0.140121  0.019634
# 1145  68.0              67.878593 -0.121407  0.014740
# 1146  23.0              23.068100  0.068100  0.004638
# 1147  11.0              11.141693  0.141693  0.020077
# 1148  27.0              27.045662  0.045662  0.002085
#
# [1149 rows x 4 columns]
# 0.8748921023046643

# %%
plt.plot(df_lstm['Err'])

# %%
plt.plot(df_lstm['Err_Sqr'])

# %%
plt.hist(df_lstm['Err'])
# Out:
# (array([7.000e+00, 3.000e+00, 4.000e+00, 1.121e+03, 8.000e+00, 1.000e+00,
#         2.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([-7.54797363, -5.31558838, -3.08320312, -0.85081787,  1.38156738,
#          3.61395264,  5.84633789,  8.07872314, 10.3111084 , 12.54349365,
#         14.77587891]),
#  <BarContainer object of 10 artists>)

# %%
from keras.models import save_model

# Save the model to a file
model.save("my_lstm_model.h5")
